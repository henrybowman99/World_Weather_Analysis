# %%
#import dependencies

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
from datetime import datetime
from citipy import citipy 
import requests
from config import weather_api_key

# %%
#create a set of random latitudes and longitudes
lats = np.random.uniform(low = -90.000, high = 90.000, size = 2000)
lngs = np.random.uniform(low = -180.000, high = 180.000, size = 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Add longs and lats to a list

coordinates = list(lat_lngs)

# %%
#create cities list
cities = []
#Identify the nearest city for each latitude and longitude combination

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #add city if it is new to cities list
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 721

# %%
print(cities[1])
# Out:
# vaini

# %%
#create an empty list to hold the wearther data
city_data = []
#create URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#Print beginning of logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

#loop through all cities in the list

for i, city in enumerate(cities):
    # Group cities in sets of 50
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
    
    city_url = url + "&q=" + city.replace(" ","+")
    
    #log URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # add 1 to the record count
    record_count += 1
    
    #Run an API request for each of the cities.
    
    try:
        #parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        # parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        
        #convert the date to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        #Append the city information into city_data list.]
        city_data.append({"City": city.title(),
                      "Lat": city_lat,
                      "Lng": city_lng,
                      "Max Temp": city_max_temp,
                      "Humidity": city_humidity,
                      "Cloudiness": city_clouds,
                      "Wind Speed": city_wind,
                      "Country": city_country,
                      "Date": city_date,
                      "Current Description": city_weather_description})
    
    #If an error is experienced, skip the city
    
    except:
        print("City not found. Skipping...")
        pass
    
# #End data retrieval
# print("-------------------------")
# print("Data Retrieval Complete")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | longjiang
# Processing Record 2 of Set 1 | vaini
# Processing Record 3 of Set 1 | muros
# Processing Record 4 of Set 1 | eilenburg
# Processing Record 5 of Set 1 | cidreira
# Processing Record 6 of Set 1 | lima
# Processing Record 7 of Set 1 | hilo
# Processing Record 8 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 1 | yellowknife
# Processing Record 11 of Set 1 | hirara
# Processing Record 12 of Set 1 | padang
# Processing Record 13 of Set 1 | tarudant
# City not found. Skipping...
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | artyk
# City not found. Skipping...
# Processing Record 16 of Set 1 | ureki
# Processing Record 17 of Set 1 | necochea
# Processing Record 18 of Set 1 | barrow
# Processing Record 19 of Set 1 | biltine
# Processing Record 20 of Set 1 | nuevitas
# Processing Record 21 of Set 1 | ossora
# Processing Record 22 of Set 1 | kapaa
# Processing Record 23 of Set 1 | port alfred
# Processing Record 24 of Set 1 | ponta do sol
# Processing Record 25 of Set 1 | nivala
# Processing Record 26 of Set 1 | selishche
# Processing Record 27 of Set 1 | kulykiv
# Processing Record 28 of Set 1 | coquimbo
# Processing Record 29 of Set 1 | rapid valley
# Processing Record 30 of Set 1 | bredasdorp
# Processing Record 31 of Set 1 | mayor pablo lagerenza
# Processing Record 32 of Set 1 | constitucion
# Processing Record 33 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 34 of Set 1 | provideniya
# Processing Record 35 of Set 1 | port elizabeth
# Processing Record 36 of Set 1 | alofi
# Processing Record 37 of Set 1 | albany
# Processing Record 38 of Set 1 | luderitz
# Processing Record 39 of Set 1 | comodoro rivadavia
# Processing Record 40 of Set 1 | atuona
# Processing Record 41 of Set 1 | touros
# Processing Record 42 of Set 1 | dikson
# Processing Record 43 of Set 1 | rikitea
# Processing Record 44 of Set 1 | namatanai
# Processing Record 45 of Set 1 | chuy
# Processing Record 46 of Set 1 | hermanus
# Processing Record 47 of Set 1 | karymskoye
# Processing Record 48 of Set 1 | nikolskoye
# Processing Record 49 of Set 1 | dhidhdhoo
# Processing Record 50 of Set 1 | logan
# Processing Record 1 of Set 2 | san patricio
# Processing Record 2 of Set 2 | codrington
# Processing Record 3 of Set 2 | busselton
# Processing Record 4 of Set 2 | mahina
# Processing Record 5 of Set 2 | hobart
# Processing Record 6 of Set 2 | inhambane
# Processing Record 7 of Set 2 | neustadt
# Processing Record 8 of Set 2 | gat
# Processing Record 9 of Set 2 | grand centre
# City not found. Skipping...
# Processing Record 10 of Set 2 | mataura
# Processing Record 11 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 2 | san quintin
# Processing Record 13 of Set 2 | ushuaia
# Processing Record 14 of Set 2 | iqaluit
# Processing Record 15 of Set 2 | maykain
# City not found. Skipping...
# Processing Record 16 of Set 2 | cape town
# Processing Record 17 of Set 2 | avarua
# Processing Record 18 of Set 2 | saint george
# Processing Record 19 of Set 2 | tessalit
# Processing Record 20 of Set 2 | san cristobal
# Processing Record 21 of Set 2 | bluff
# Processing Record 22 of Set 2 | san-pedro
# Processing Record 23 of Set 2 | mount isa
# Processing Record 24 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 2 | zhezkazgan
# Processing Record 26 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 2 | kamenka
# Processing Record 31 of Set 2 | kokoda
# Processing Record 32 of Set 2 | tiksi
# Processing Record 33 of Set 2 | karaton
# Processing Record 34 of Set 2 | hasaki
# Processing Record 35 of Set 2 | emerald
# Processing Record 36 of Set 2 | saldanha
# Processing Record 37 of Set 2 | lampa
# Processing Record 38 of Set 2 | qaanaaq
# Processing Record 39 of Set 2 | whitehorse
# Processing Record 40 of Set 2 | mountain home
# Processing Record 41 of Set 2 | zalantun
# Processing Record 42 of Set 2 | thompson
# Processing Record 43 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 44 of Set 2 | ardabil
# Processing Record 45 of Set 2 | saskylakh
# Processing Record 46 of Set 2 | cairns
# Processing Record 47 of Set 2 | hithadhoo
# Processing Record 48 of Set 2 | voznesenskoye
# Processing Record 49 of Set 2 | bud
# Processing Record 50 of Set 2 | esperance
# Processing Record 1 of Set 3 | george town
# Processing Record 2 of Set 3 | promakhoi
# City not found. Skipping...
# Processing Record 3 of Set 3 | jamestown
# Processing Record 4 of Set 3 | luang prabang
# Processing Record 5 of Set 3 | bethel
# Processing Record 6 of Set 3 | naryan-mar
# Processing Record 7 of Set 3 | abu dhabi
# Processing Record 8 of Set 3 | fairbanks
# Processing Record 9 of Set 3 | okhotsk
# Processing Record 10 of Set 3 | kodiak
# Processing Record 11 of Set 3 | tuktoyaktuk
# Processing Record 12 of Set 3 | kavieng
# Processing Record 13 of Set 3 | arraial do cabo
# Processing Record 14 of Set 3 | antalaha
# Processing Record 15 of Set 3 | new norfolk
# Processing Record 16 of Set 3 | saint-pierre
# Processing Record 17 of Set 3 | carnarvon
# Processing Record 18 of Set 3 | pacific grove
# Processing Record 19 of Set 3 | eastbourne
# Processing Record 20 of Set 3 | butaritari
# Processing Record 21 of Set 3 | lata
# Processing Record 22 of Set 3 | east london
# Processing Record 23 of Set 3 | villa bruzual
# Processing Record 24 of Set 3 | tondano
# Processing Record 25 of Set 3 | bambous virieux
# Processing Record 26 of Set 3 | karratha
# Processing Record 27 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 28 of Set 3 | sampit
# Processing Record 29 of Set 3 | pipirig
# Processing Record 30 of Set 3 | manuk mangkaw
# Processing Record 31 of Set 3 | souillac
# Processing Record 32 of Set 3 | viedma
# Processing Record 33 of Set 3 | lorengau
# Processing Record 34 of Set 3 | vardo
# Processing Record 35 of Set 3 | moron
# Processing Record 36 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 37 of Set 3 | eydhafushi
# Processing Record 38 of Set 3 | ventspils
# Processing Record 39 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 40 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 41 of Set 3 | pisco
# Processing Record 42 of Set 3 | puerto ayora
# Processing Record 43 of Set 3 | riviere-au-renard
# Processing Record 44 of Set 3 | hualmay
# Processing Record 45 of Set 3 | poum
# Processing Record 46 of Set 3 | lufilufi
# Processing Record 47 of Set 3 | buala
# Processing Record 48 of Set 3 | juruti
# Processing Record 49 of Set 3 | namibe
# Processing Record 50 of Set 3 | tautira
# Processing Record 1 of Set 4 | mahebourg
# Processing Record 2 of Set 4 | bukama
# Processing Record 3 of Set 4 | airai
# Processing Record 4 of Set 4 | las vegas
# Processing Record 5 of Set 4 | torbay
# Processing Record 6 of Set 4 | ribeira grande
# Processing Record 7 of Set 4 | talavera
# Processing Record 8 of Set 4 | narsaq
# Processing Record 9 of Set 4 | husavik
# Processing Record 10 of Set 4 | katsuura
# Processing Record 11 of Set 4 | ilulissat
# Processing Record 12 of Set 4 | sao filipe
# Processing Record 13 of Set 4 | high level
# Processing Record 14 of Set 4 | vila velha
# Processing Record 15 of Set 4 | carballo
# Processing Record 16 of Set 4 | siguiri
# Processing Record 17 of Set 4 | khatanga
# Processing Record 18 of Set 4 | ban nahin
# Processing Record 19 of Set 4 | nome
# Processing Record 20 of Set 4 | damghan
# Processing Record 21 of Set 4 | milkovo
# Processing Record 22 of Set 4 | armeria
# Processing Record 23 of Set 4 | arona
# Processing Record 24 of Set 4 | darlington
# Processing Record 25 of Set 4 | saint-philippe
# Processing Record 26 of Set 4 | porto velho
# Processing Record 27 of Set 4 | muir of ord
# Processing Record 28 of Set 4 | pemangkat
# Processing Record 29 of Set 4 | pechora
# Processing Record 30 of Set 4 | opuwo
# Processing Record 31 of Set 4 | rawson
# Processing Record 32 of Set 4 | baiyin
# Processing Record 33 of Set 4 | troitsko-pechorsk
# Processing Record 34 of Set 4 | aksarka
# Processing Record 35 of Set 4 | sovetskiy
# Processing Record 36 of Set 4 | hami
# Processing Record 37 of Set 4 | plettenberg bay
# Processing Record 38 of Set 4 | mogocha
# Processing Record 39 of Set 4 | tasiilaq
# Processing Record 40 of Set 4 | centralia
# Processing Record 41 of Set 4 | fortuna
# Processing Record 42 of Set 4 | tavares
# Processing Record 43 of Set 4 | ancud
# Processing Record 44 of Set 4 | thermon
# City not found. Skipping...
# Processing Record 45 of Set 4 | port-cartier
# Processing Record 46 of Set 4 | flin flon
# Processing Record 47 of Set 4 | havoysund
# Processing Record 48 of Set 4 | kruisfontein
# Processing Record 49 of Set 4 | kayerkan
# Processing Record 50 of Set 4 | birin
# Processing Record 1 of Set 5 | atakpame
# Processing Record 2 of Set 5 | quimper
# Processing Record 3 of Set 5 | tandil
# Processing Record 4 of Set 5 | port-gentil
# Processing Record 5 of Set 5 | dzhusaly
# City not found. Skipping...
# Processing Record 6 of Set 5 | durant
# Processing Record 7 of Set 5 | port hardy
# Processing Record 8 of Set 5 | berbera
# Processing Record 9 of Set 5 | vostok
# Processing Record 10 of Set 5 | quelimane
# Processing Record 11 of Set 5 | rorvik
# Processing Record 12 of Set 5 | byron bay
# Processing Record 13 of Set 5 | amapa
# Processing Record 14 of Set 5 | sorland
# Processing Record 15 of Set 5 | severo-kurilsk
# Processing Record 16 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 5 | faanui
# Processing Record 18 of Set 5 | billings
# Processing Record 19 of Set 5 | chumikan
# Processing Record 20 of Set 5 | ballina
# Processing Record 21 of Set 5 | georgetown
# Processing Record 22 of Set 5 | porto walter
# Processing Record 23 of Set 5 | tromso
# Processing Record 24 of Set 5 | paso de los toros
# Processing Record 25 of Set 5 | thunder bay
# Processing Record 26 of Set 5 | upernavik
# Processing Record 27 of Set 5 | cayenne
# Processing Record 28 of Set 5 | vestmannaeyjar
# Processing Record 29 of Set 5 | sitka
# Processing Record 30 of Set 5 | aubel
# Processing Record 31 of Set 5 | vila franca do campo
# Processing Record 32 of Set 5 | pedasi
# Processing Record 33 of Set 5 | bengkulu
# Processing Record 34 of Set 5 | lebu
# Processing Record 35 of Set 5 | longyearbyen
# Processing Record 36 of Set 5 | kargasok
# Processing Record 37 of Set 5 | yomitan
# City not found. Skipping...
# Processing Record 38 of Set 5 | kavaratti
# Processing Record 39 of Set 5 | conceicao do araguaia
# Processing Record 40 of Set 5 | yulara
# Processing Record 41 of Set 5 | dingle
# Processing Record 42 of Set 5 | guymon
# Processing Record 43 of Set 5 | aklavik
# Processing Record 44 of Set 5 | doha
# Processing Record 45 of Set 5 | magadi
# Processing Record 46 of Set 5 | fereydun kenar
# Processing Record 47 of Set 5 | yola
# Processing Record 48 of Set 5 | yeppoon
# Processing Record 49 of Set 5 | cabedelo
# Processing Record 50 of Set 5 | skibbereen
# Processing Record 1 of Set 6 | clyde river
# Processing Record 2 of Set 6 | cap malheureux
# Processing Record 3 of Set 6 | burnie
# Processing Record 4 of Set 6 | brigham city
# Processing Record 5 of Set 6 | raudeberg
# Processing Record 6 of Set 6 | maldonado
# Processing Record 7 of Set 6 | lavrentiya
# Processing Record 8 of Set 6 | paita
# Processing Record 9 of Set 6 | mar del plata
# Processing Record 10 of Set 6 | hofn
# Processing Record 11 of Set 6 | rostovka
# Processing Record 12 of Set 6 | fez
# Processing Record 13 of Set 6 | eureka
# Processing Record 14 of Set 6 | houston
# Processing Record 15 of Set 6 | bela vista
# Processing Record 16 of Set 6 | saint-augustin
# Processing Record 17 of Set 6 | staunton
# Processing Record 18 of Set 6 | talnakh
# Processing Record 19 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 6 | nalut
# Processing Record 21 of Set 6 | geraldton
# Processing Record 22 of Set 6 | asasa
# Processing Record 23 of Set 6 | klyuchi
# Processing Record 24 of Set 6 | alta floresta
# Processing Record 25 of Set 6 | bandarbeyla
# Processing Record 26 of Set 6 | guerrero negro
# Processing Record 27 of Set 6 | vanavara
# Processing Record 28 of Set 6 | lagoa
# Processing Record 29 of Set 6 | brigantine
# Processing Record 30 of Set 6 | havre-saint-pierre
# Processing Record 31 of Set 6 | ust-kuyga
# Processing Record 32 of Set 6 | victoria
# Processing Record 33 of Set 6 | ronneby
# Processing Record 34 of Set 6 | cherskiy
# Processing Record 35 of Set 6 | ust-ilimsk
# Processing Record 36 of Set 6 | miri
# Processing Record 37 of Set 6 | kiruna
# Processing Record 38 of Set 6 | apache junction
# Processing Record 39 of Set 6 | port lincoln
# Processing Record 40 of Set 6 | hambantota
# Processing Record 41 of Set 6 | itarema
# Processing Record 42 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 6 | simao
# Processing Record 44 of Set 6 | longlac
# City not found. Skipping...
# Processing Record 45 of Set 6 | college
# Processing Record 46 of Set 6 | naron
# Processing Record 47 of Set 6 | saint-joseph
# Processing Record 48 of Set 6 | lasa
# Processing Record 49 of Set 6 | cookshire
# City not found. Skipping...
# Processing Record 50 of Set 6 | porto novo
# Processing Record 1 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 7 | bandar
# Processing Record 3 of Set 7 | serra negra
# Processing Record 4 of Set 7 | shimoda
# Processing Record 5 of Set 7 | oudtshoorn
# Processing Record 6 of Set 7 | mentok
# City not found. Skipping...
# Processing Record 7 of Set 7 | castro
# Processing Record 8 of Set 7 | chicama
# Processing Record 9 of Set 7 | iracoubo
# Processing Record 10 of Set 7 | salalah
# Processing Record 11 of Set 7 | cabo san lucas
# Processing Record 12 of Set 7 | chokurdakh
# Processing Record 13 of Set 7 | nanortalik
# Processing Record 14 of Set 7 | ponta delgada
# Processing Record 15 of Set 7 | shafranovo
# Processing Record 16 of Set 7 | maniwaki
# Processing Record 17 of Set 7 | kaeo
# Processing Record 18 of Set 7 | akdepe
# Processing Record 19 of Set 7 | caravelas
# Processing Record 20 of Set 7 | lianran
# Processing Record 21 of Set 7 | galgani
# City not found. Skipping...
# Processing Record 22 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 7 | isla vista
# Processing Record 24 of Set 7 | campbell river
# Processing Record 25 of Set 7 | peleduy
# Processing Record 26 of Set 7 | kondinskoye
# Processing Record 27 of Set 7 | mareeba
# Processing Record 28 of Set 7 | sao joao da barra
# Processing Record 29 of Set 7 | zhetysay
# Processing Record 30 of Set 7 | ostrovnoy
# Processing Record 31 of Set 7 | portland
# Processing Record 32 of Set 7 | palenque
# Processing Record 33 of Set 7 | pevek
# Processing Record 34 of Set 7 | dicabisagan
# Processing Record 35 of Set 7 | suntar
# Processing Record 36 of Set 7 | katherine
# Processing Record 37 of Set 7 | ruidoso
# Processing Record 38 of Set 7 | noumea
# Processing Record 39 of Set 7 | puerto del rosario
# Processing Record 40 of Set 7 | nakhon phanom
# Processing Record 41 of Set 7 | jaysingpur
# Processing Record 42 of Set 7 | kloulklubed
# Processing Record 43 of Set 7 | rabaul
# Processing Record 44 of Set 7 | sangar
# Processing Record 45 of Set 7 | canchungo
# Processing Record 46 of Set 7 | abu samrah
# Processing Record 47 of Set 7 | cape coast
# Processing Record 48 of Set 7 | grindavik
# Processing Record 49 of Set 7 | santa marta
# Processing Record 50 of Set 7 | shubarkuduk
# Processing Record 1 of Set 8 | greiz
# Processing Record 2 of Set 8 | gazni
# City not found. Skipping...
# Processing Record 3 of Set 8 | gweta
# Processing Record 4 of Set 8 | kaitangata
# Processing Record 5 of Set 8 | ulladulla
# Processing Record 6 of Set 8 | waslala
# Processing Record 7 of Set 8 | zhicheng
# Processing Record 8 of Set 8 | pavlodar
# Processing Record 9 of Set 8 | adre
# Processing Record 10 of Set 8 | mana
# Processing Record 11 of Set 8 | salina cruz
# Processing Record 12 of Set 8 | atambua
# Processing Record 13 of Set 8 | at-bashi
# Processing Record 14 of Set 8 | beringovskiy
# Processing Record 15 of Set 8 | santa isabel do rio negro
# Processing Record 16 of Set 8 | ayagoz
# Processing Record 17 of Set 8 | beloha
# Processing Record 18 of Set 8 | tura
# Processing Record 19 of Set 8 | ninotsminda
# Processing Record 20 of Set 8 | calbuco
# Processing Record 21 of Set 8 | luanda
# Processing Record 22 of Set 8 | sumbe
# Processing Record 23 of Set 8 | oranjemund
# Processing Record 24 of Set 8 | delta del tigre
# Processing Record 25 of Set 8 | mizque
# Processing Record 26 of Set 8 | salamiyah
# Processing Record 27 of Set 8 | sinnamary
# Processing Record 28 of Set 8 | tsaratanana
# Processing Record 29 of Set 8 | itigi
# Processing Record 30 of Set 8 | tazovskiy
# Processing Record 31 of Set 8 | tynda
# Processing Record 32 of Set 8 | ornskoldsvik
# Processing Record 33 of Set 8 | port shepstone
# Processing Record 34 of Set 8 | grenville
# Processing Record 35 of Set 8 | jalgaon
# Processing Record 36 of Set 8 | jacareacanga
# Processing Record 37 of Set 8 | waingapu
# Processing Record 38 of Set 8 | nishihara
# Processing Record 39 of Set 8 | basco
# Processing Record 40 of Set 8 | lompoc
# Processing Record 41 of Set 8 | amahai
# Processing Record 42 of Set 8 | maua
# Processing Record 43 of Set 8 | zhigansk
# Processing Record 44 of Set 8 | alugan
# Processing Record 45 of Set 8 | iranshahr
# Processing Record 46 of Set 8 | sakakah
# Processing Record 47 of Set 8 | guaraniacu
# Processing Record 48 of Set 8 | auki
# Processing Record 49 of Set 8 | takoradi
# Processing Record 50 of Set 8 | keetmanshoop
# Processing Record 1 of Set 9 | asau
# Processing Record 2 of Set 9 | barrhead
# Processing Record 3 of Set 9 | mudyuga
# City not found. Skipping...
# Processing Record 4 of Set 9 | belgrade
# Processing Record 5 of Set 9 | okhtyrka
# Processing Record 6 of Set 9 | subate
# Processing Record 7 of Set 9 | prince rupert
# Processing Record 8 of Set 9 | voh
# Processing Record 9 of Set 9 | kahului
# Processing Record 10 of Set 9 | cockburn town
# Processing Record 11 of Set 9 | tulun
# Processing Record 12 of Set 9 | tuatapere
# Processing Record 13 of Set 9 | wabana
# Processing Record 14 of Set 9 | omboue
# Processing Record 15 of Set 9 | bilma
# Processing Record 16 of Set 9 | khandyga
# Processing Record 17 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 18 of Set 9 | chernoyerkovskaya
# Processing Record 19 of Set 9 | dalbandin
# Processing Record 20 of Set 9 | marawi
# Processing Record 21 of Set 9 | coahuayana
# Processing Record 22 of Set 9 | safwah
# City not found. Skipping...
# Processing Record 23 of Set 9 | ixtapa
# Processing Record 24 of Set 9 | kununurra
# Processing Record 25 of Set 9 | urumqi
# Processing Record 26 of Set 9 | ileza
# Processing Record 27 of Set 9 | scottsburgh
# City not found. Skipping...
# Processing Record 28 of Set 9 | mount gambier
# Processing Record 29 of Set 9 | manokwari
# Processing Record 30 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 31 of Set 9 | shediac
# Processing Record 32 of Set 9 | issoudun
# Processing Record 33 of Set 9 | vestmanna
# Processing Record 34 of Set 9 | tilichiki
# Processing Record 35 of Set 9 | oktyabrskiy
# Processing Record 36 of Set 9 | kichera
# Processing Record 37 of Set 9 | jonava
# Processing Record 38 of Set 9 | traverse city
# Processing Record 39 of Set 9 | atar
# Processing Record 40 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 9 | pontes e lacerda
# Processing Record 42 of Set 9 | mehamn
# Processing Record 43 of Set 9 | pakdasht
# Processing Record 44 of Set 9 | christchurch
# Processing Record 45 of Set 9 | broken hill
# Processing Record 46 of Set 9 | puerto escondido
# Processing Record 47 of Set 9 | linjiang
# Processing Record 48 of Set 9 | goderich
# Processing Record 49 of Set 9 | sambava
# Processing Record 50 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 1 of Set 10 | avera
# Processing Record 2 of Set 10 | palmer
# Processing Record 3 of Set 10 | mazagao
# Processing Record 4 of Set 10 | malakal
# Processing Record 5 of Set 10 | tucuman
# Processing Record 6 of Set 10 | hovd
# Processing Record 7 of Set 10 | irbil
# Processing Record 8 of Set 10 | dukat
# Processing Record 9 of Set 10 | luwuk
# Processing Record 10 of Set 10 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 11 of Set 10 | los llanos de aridane
# Processing Record 12 of Set 10 | venice
# Processing Record 13 of Set 10 | guicheng
# City not found. Skipping...
# Processing Record 14 of Set 10 | laguna
# Processing Record 15 of Set 10 | saint-georges
# Processing Record 16 of Set 10 | harsin
# Processing Record 17 of Set 10 | sonta
# Processing Record 18 of Set 10 | tambura
# Processing Record 19 of Set 10 | wajima
# Processing Record 20 of Set 10 | talara
# Processing Record 21 of Set 10 | huarmey
# Processing Record 22 of Set 10 | kalmar
# Processing Record 23 of Set 10 | chute-aux-outardes
# Processing Record 24 of Set 10 | jalu
# Processing Record 25 of Set 10 | huanren
# Processing Record 26 of Set 10 | bemidji
# Processing Record 27 of Set 10 | sabalgarh
# Processing Record 28 of Set 10 | poya
# Processing Record 29 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 30 of Set 10 | klaksvik
# Processing Record 31 of Set 10 | dharchula
# Processing Record 32 of Set 10 | wilmington
# Processing Record 33 of Set 10 | lixourion
# Processing Record 34 of Set 10 | maarianhamina
# Processing Record 35 of Set 10 | rumoi
# Processing Record 36 of Set 10 | mukilteo
# Processing Record 37 of Set 10 | altay
# Processing Record 38 of Set 10 | bismarck
# Processing Record 39 of Set 10 | yatou
# Processing Record 40 of Set 10 | altamira
# Processing Record 41 of Set 10 | saint anthony
# Processing Record 42 of Set 10 | maicao
# Processing Record 43 of Set 10 | evensk
# Processing Record 44 of Set 10 | balykshi
# Processing Record 45 of Set 10 | puerto narino
# Processing Record 46 of Set 10 | san carlos de bariloche
# Processing Record 47 of Set 10 | northam
# Processing Record 48 of Set 10 | tayoltita
# Processing Record 49 of Set 10 | helena
# Processing Record 50 of Set 10 | macklin
# Processing Record 1 of Set 11 | bubaque
# Processing Record 2 of Set 11 | salta
# Processing Record 3 of Set 11 | svetlogorsk
# Processing Record 4 of Set 11 | tashla
# Processing Record 5 of Set 11 | cap estate
# Processing Record 6 of Set 11 | launceston
# Processing Record 7 of Set 11 | do gonbadan
# Processing Record 8 of Set 11 | nouadhibou
# Processing Record 9 of Set 11 | morshansk
# Processing Record 10 of Set 11 | shitanjing
# Processing Record 11 of Set 11 | goedereede
# Processing Record 12 of Set 11 | kholmskaya
# Processing Record 13 of Set 11 | solnechnyy
# Processing Record 14 of Set 11 | ojinaga
# Processing Record 15 of Set 11 | mbulu
# Processing Record 16 of Set 11 | harper
# Processing Record 17 of Set 11 | pemba
# Processing Record 18 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 19 of Set 11 | ciudad bolivar
# Processing Record 20 of Set 11 | kalmunai
# Processing Record 21 of Set 11 | iraan
# Processing Record 22 of Set 11 | bulgan
# Processing Record 23 of Set 11 | polunochnoye
# Processing Record 24 of Set 11 | meadow lake
# Processing Record 25 of Set 11 | santo angelo
# Processing Record 26 of Set 11 | belyy yar
# Processing Record 27 of Set 11 | novosheshminsk
# Processing Record 28 of Set 11 | hammerfest
# Processing Record 29 of Set 11 | macenta
# Processing Record 30 of Set 11 | tsiroanomandidy
# Processing Record 31 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 32 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 33 of Set 11 | sola
# Processing Record 34 of Set 11 | norman wells
# Processing Record 35 of Set 11 | honningsvag
# Processing Record 36 of Set 11 | pustoshka
# Processing Record 37 of Set 11 | ahar
# Processing Record 38 of Set 11 | houma
# Processing Record 39 of Set 11 | katangli
# Processing Record 40 of Set 11 | ambodifototra
# City not found. Skipping...
# Processing Record 41 of Set 11 | mullaitivu
# City not found. Skipping...
# Processing Record 42 of Set 11 | jishou
# Processing Record 43 of Set 11 | sistranda
# Processing Record 44 of Set 11 | mount vernon
# Processing Record 45 of Set 11 | mandal
# Processing Record 46 of Set 11 | alice springs
# Processing Record 47 of Set 11 | olinda
# Processing Record 48 of Set 11 | leningradskiy
# Processing Record 49 of Set 11 | waipawa
# Processing Record 50 of Set 11 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 1 of Set 12 | cabimas
# Processing Record 2 of Set 12 | moree
# Processing Record 3 of Set 12 | goodyear
# Processing Record 4 of Set 12 | saint paul
# Processing Record 5 of Set 12 | luba
# Processing Record 6 of Set 12 | edea
# Processing Record 7 of Set 12 | srednekolymsk
# Processing Record 8 of Set 12 | howick
# Processing Record 9 of Set 12 | shankargarh
# Processing Record 10 of Set 12 | jaciara
# Processing Record 11 of Set 12 | san jose
# Processing Record 12 of Set 12 | golfito
# Processing Record 13 of Set 12 | les cayes
# Processing Record 14 of Set 12 | oeiras do para
# Processing Record 15 of Set 12 | sao felix do xingu
# Processing Record 16 of Set 12 | west wendover
# Processing Record 17 of Set 12 | bonavista
# Processing Record 18 of Set 12 | kieta
# Processing Record 19 of Set 12 | barreirinhas
# Processing Record 20 of Set 12 | buariki
# City not found. Skipping...
# Processing Record 21 of Set 12 | contamana
# Processing Record 22 of Set 12 | adrar
# Processing Record 23 of Set 12 | la rioja
# Processing Record 24 of Set 12 | damaturu
# Processing Record 25 of Set 12 | sofiysk
# City not found. Skipping...
# Processing Record 26 of Set 12 | culpeper
# Processing Record 27 of Set 12 | isiro
# Processing Record 28 of Set 12 | moreira sales
# Processing Record 29 of Set 12 | surt
# Processing Record 30 of Set 12 | vuktyl
# Processing Record 31 of Set 12 | dwarka
# Processing Record 32 of Set 12 | ahipara
# Processing Record 33 of Set 12 | gumushane
# City not found. Skipping...
# Processing Record 34 of Set 12 | rabak
# Processing Record 35 of Set 12 | dapaong
# Processing Record 36 of Set 12 | new bern
# Processing Record 37 of Set 12 | ganta
# Processing Record 38 of Set 12 | kaa-khem
# Processing Record 39 of Set 12 | fort nelson
# Processing Record 40 of Set 12 | hanmer springs
# Processing Record 41 of Set 12 | rio cuarto
# Processing Record 42 of Set 12 | lhuntshi
# City not found. Skipping...
# Processing Record 43 of Set 12 | faya
# Processing Record 44 of Set 12 | nizwa
# Processing Record 45 of Set 12 | jiayuguan
# Processing Record 46 of Set 12 | talawdi
# City not found. Skipping...
# Processing Record 47 of Set 12 | udupi
# Processing Record 48 of Set 12 | richards bay
# Processing Record 49 of Set 12 | isangel
# Processing Record 50 of Set 12 | chiplun
# Processing Record 1 of Set 13 | taldan
# Processing Record 2 of Set 13 | pombas
# Processing Record 3 of Set 13 | alyangula
# Processing Record 4 of Set 13 | sabla
# Processing Record 5 of Set 13 | orange cove
# Processing Record 6 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 7 of Set 13 | goundam
# Processing Record 8 of Set 13 | oranjestad
# Processing Record 9 of Set 13 | wanning
# Processing Record 10 of Set 13 | middelburg
# Processing Record 11 of Set 13 | mujiayingzi
# Processing Record 12 of Set 13 | ellisras
# Processing Record 13 of Set 13 | sorong
# Processing Record 14 of Set 13 | ca mau
# Processing Record 15 of Set 13 | ocampo
# Processing Record 16 of Set 13 | rocha
# Processing Record 17 of Set 13 | riverton
# Processing Record 18 of Set 13 | villarrica
# Processing Record 19 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 20 of Set 13 | berwick
# Processing Record 21 of Set 13 | urengoy
# Processing Record 22 of Set 13 | iralaya
# Processing Record 23 of Set 13 | uwayl
# City not found. Skipping...
# Processing Record 24 of Set 13 | umea
# Processing Record 25 of Set 13 | nioro
# Processing Record 26 of Set 13 | vieste
# Processing Record 27 of Set 13 | hamilton
# Processing Record 28 of Set 13 | komsomolskiy
# Processing Record 29 of Set 13 | bowen
# Processing Record 30 of Set 13 | boca do acre
# Processing Record 31 of Set 13 | kautokeino
# Processing Record 32 of Set 13 | bage
# Processing Record 33 of Set 13 | odweyne
# Processing Record 34 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 35 of Set 13 | sao gabriel da cachoeira
# Processing Record 36 of Set 13 | okato
# Processing Record 37 of Set 13 | margate
# Processing Record 38 of Set 13 | terrace
# Processing Record 39 of Set 13 | vanimo
# Processing Record 40 of Set 13 | manta
# Processing Record 41 of Set 13 | bonthe
# Processing Record 42 of Set 13 | krasnoselkup
# Processing Record 43 of Set 13 | coihaique
# Processing Record 44 of Set 13 | nadym
# Processing Record 45 of Set 13 | qinhuangdao
# Processing Record 46 of Set 13 | bathurst
# Processing Record 47 of Set 13 | usmajac
# Processing Record 48 of Set 13 | almaznyy
# Processing Record 49 of Set 13 | ewa beach
# Processing Record 50 of Set 13 | chase
# Processing Record 1 of Set 14 | mecca
# Processing Record 2 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 3 of Set 14 | praia
# Processing Record 4 of Set 14 | yurimaguas
# Processing Record 5 of Set 14 | nuuk
# Processing Record 6 of Set 14 | banjarmasin
# Processing Record 7 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 8 of Set 14 | muzhi
# Processing Record 9 of Set 14 | chimbote
# Processing Record 10 of Set 14 | sioux lookout
# Processing Record 11 of Set 14 | kaitong
# Processing Record 12 of Set 14 | kathmandu
# Processing Record 13 of Set 14 | lincoln
# Processing Record 14 of Set 14 | dakoro
# Processing Record 15 of Set 14 | tual
# Processing Record 16 of Set 14 | silver city
# Processing Record 17 of Set 14 | haines junction
# Processing Record 18 of Set 14 | bestobe
# Processing Record 19 of Set 14 | ndioum
# Processing Record 20 of Set 14 | vangaindrano
# Processing Record 21 of Set 14 | zhifang
# Processing Record 22 of Set 14 | hobyo
# Processing Record 23 of Set 14 | ginir
# Processing Record 24 of Set 14 | santa maria
# Processing Record 25 of Set 14 | dudinka
# Processing Record 26 of Set 14 | payette
# Processing Record 27 of Set 14 | harqalah
# Processing Record 28 of Set 14 | biak
# Processing Record 29 of Set 14 | tanout
# Processing Record 30 of Set 14 | campo grande
# Processing Record 31 of Set 14 | luganville
# Processing Record 32 of Set 14 | yumen
# Processing Record 33 of Set 14 | lodja
# Processing Record 34 of Set 14 | pietersburg
# Processing Record 35 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 36 of Set 14 | la asuncion
# Processing Record 37 of Set 14 | piste
# Processing Record 38 of Set 14 | bac lieu
# Processing Record 39 of Set 14 | kemijarvi
# Processing Record 40 of Set 14 | flinders
# Processing Record 41 of Set 14 | tunduru
# City not found. Skipping...
# Processing Record 42 of Set 14 | berlevag
# Processing Record 43 of Set 14 | marrakesh
# Processing Record 44 of Set 14 | sohag
# Processing Record 45 of Set 14 | horta
# Processing Record 46 of Set 14 | coulihaut
# City not found. Skipping...
# Processing Record 47 of Set 14 | arys
# Processing Record 48 of Set 14 | nigde
# Processing Record 49 of Set 14 | lexington park
# Processing Record 50 of Set 14 | san andres
# Processing Record 1 of Set 15 | miramar
# Processing Record 2 of Set 15 | miranorte
# City not found. Skipping...
# Processing Record 3 of Set 15 | chichihualco
# Processing Record 4 of Set 15 | tazmalt
# Processing Record 5 of Set 15 | neiafu
# Processing Record 6 of Set 15 | turukhansk
# Processing Record 7 of Set 15 | chiang klang
# Processing Record 8 of Set 15 | carutapera
# Processing Record 9 of Set 15 | bafq
# Processing Record 10 of Set 15 | turtkul
# City not found. Skipping...
# Processing Record 11 of Set 15 | nouakchott
# Processing Record 12 of Set 15 | sturgeon bay
# Processing Record 13 of Set 15 | mangrol
# Processing Record 14 of Set 15 | muisne
# Processing Record 15 of Set 15 | wanxian
# Processing Record 16 of Set 15 | leshukonskoye
# Processing Record 17 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 18 of Set 15 | chacabuco
# Processing Record 19 of Set 15 | labuhan
# Processing Record 20 of Set 15 | kirksville
# Processing Record 21 of Set 15 | henties bay

# %%
city_weather_data_df = pd.DataFrame(city_data)
city_weather_data_df.drop(["Date"],axis = 1)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Longjiang  47.3303  123.1836      3.33        97         100
# 1            Vaini -21.2000 -175.2000     82.56        83          40
# 2            Muros  42.7762   -9.0603     54.23        91          18
# 3        Eilenburg  51.4598   12.6334     49.24        68         100
# 4         Cidreira -30.1811  -50.2056     72.39        69          29
# ..             ...      ...       ...       ...       ...         ...
# 652  Leshukonskoye  64.8989   45.7622     17.20        94         100
# 653      Chacabuco -34.6417  -60.4739     81.81        40           0
# 654        Labuhan  -6.8844  112.2051     77.34        89         100
# 655     Kirksville  40.1948  -92.5833     47.05        49          40
# 656    Henties Bay -22.1160   14.2845     67.86        85           3
#
#      Wind Speed Country Current Description
# 0          5.70      CN     overcast clouds
# 1         10.36      TO    scattered clouds
# 2          5.97      ES          few clouds
# 3          9.01      DE     overcast clouds
# 4         11.88      BR    scattered clouds
# ..          ...     ...                 ...
# 652        9.66      RU          light snow
# 653        6.78      AR           clear sky
# 654        9.10      ID     overcast clouds
# 655       14.97      US    scattered clouds
# 656        2.19      NA           clear sky
#
# [657 rows x 9 columns]

# %%
#reorder city data df columns
new_column_order = ["City", "Country","Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_weather_data_df = city_weather_data_df[new_column_order]
city_weather_data_df
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Longjiang      CN  47.3303  123.1836      3.33        97         100
# 1            Vaini      TO -21.2000 -175.2000     82.56        83          40
# 2            Muros      ES  42.7762   -9.0603     54.23        91          18
# 3        Eilenburg      DE  51.4598   12.6334     49.24        68         100
# 4         Cidreira      BR -30.1811  -50.2056     72.39        69          29
# ..             ...     ...      ...       ...       ...       ...         ...
# 652  Leshukonskoye      RU  64.8989   45.7622     17.20        94         100
# 653      Chacabuco      AR -34.6417  -60.4739     81.81        40           0
# 654        Labuhan      ID  -6.8844  112.2051     77.34        89         100
# 655     Kirksville      US  40.1948  -92.5833     47.05        49          40
# 656    Henties Bay      NA -22.1160   14.2845     67.86        85           3
#
#      Wind Speed Current Description
# 0          5.70     overcast clouds
# 1         10.36    scattered clouds
# 2          5.97          few clouds
# 3          9.01     overcast clouds
# 4         11.88    scattered clouds
# ..          ...                 ...
# 652        9.66          light snow
# 653        6.78           clear sky
# 654        9.10     overcast clouds
# 655       14.97    scattered clouds
# 656        2.19           clear sky
#
# [657 rows x 9 columns]

# %%
#create CSV file
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# export city_data into CSV
city_weather_data_df.to_csv(output_data_file, index_label = "City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
#create lat vs Max temp scatter plot
#import time module
import time

#Build the scatter plot for latitude vs. max temp
plt.scatter(lats, max_temps, edgecolor = "black", linewidths = 1, marker = "o", alpha = 0.8, label = "Cities")
#add other properties
plt.title(f"City Latitude vs. Max Temperature " + time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
plt.show
plt.savefig("weather_data/Fig1.png")

# %%
#import time module
import time

#Build the scatter plot for latitude vs. max temp
plt.scatter(lats, humidity, edgecolor = "black", linewidths = 1, marker = "o", alpha = 0.8, label = "Cities")
#add other properties
plt.title(f"City Latitude vs. Humidity " + time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.show
plt.savefig("weather_data/Fig2.png")

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,cloudiness,edgecolor="black", linewidths=1, marker="o",alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,wind_speed, edgecolor="black", linewidths=1, marker="o",alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
#import linregress
from scipy.stats import linregress

#crate function for linrer regression and plit regresion line
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    #run regression on hemisphere weather data
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
    #calculate "y values" from the slope and int
    regress_values = x_values*slope + intercept
    #get the equation of the line
    line_eq = "y =" + str(round(slope, 2)) + "x + " + str(round(intercept,2))
    #create scatter plot and reg line
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, "r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
index13 = city_data_df.loc[13]
index13

# %%
#create df for norther hemi
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"]>=0)]
northern_hemi_df

# %%
#create df for southern hemi
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"]<0)]
southern_hemi_df

# %%
#linreg on northern hemi
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
#call the function
plot_linear_regression(x_values, y_values,'Linear Regression on the Northern Hemisphere for Maximum Temperature', 'Max Temp', (10,-40))

# %%
#linreg on southern hemi
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
#call the function
plot_linear_regression(x_values, y_values,'Linear Regression on the Southern Hemisphere for Maximum Temperature', 'Max Temp', (-50,40))

# %%
#linear regression of humidity on latitude for n hemi
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, 
                       'Linear Regression on the Northern Hemisphere  for % Humidity',  '% Humidity', (40,10))

# %%
#linear regression of humidity on latitude for s hemi
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, 
                       'Linear Regression on the Southern Hemisphere  for % Humidity',  '% Humidity', (-50,15))

# %%
#linear regression of cloudiness on latitude for n hemi

x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, 
                       'Linear Regression on the Northern Hemisphere  for % Cloudiness',  '% Cloudiness', (47,0))

# %%
#linear regression of cloudiness on latitude for s hemi
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, 
                       'Linear Regression on the Southern Hemisphere  for % Cloudiness',  '% Cloudiness', (-55,10))

# %%
# Linear regression of wind speed on lat for n hemi
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \n for Wind Speed', 'Wind Speed',(40,35))

# %%
# Linear regression of wind speed on lat for s hemi
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for Wind Speed', 'Wind Speed',(-50,22))
